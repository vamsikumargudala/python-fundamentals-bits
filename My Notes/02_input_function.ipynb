# %% [markdown]
# ## Basic Usage

# %%
input('What is your name? ')
# Out:
# 'Vamsi'

# %%
# Without prompt
input()
# Out:
# 'Vamsi'

# %% [markdown]
# ## Storing Input in a Variable

# %%
name = input('What is your name? ')
print('Welcome', name)
# Out:
# Welcome Vamsi

# %% [markdown]
# ## Input is Always a String
#
# Even if the user types a number, `input()` returns a string.

# %%
age = input('Enter your age: ')
print('Age:', age)
print('Type:', type(age))  # <class 'str'>
# Out:
# Age: 25
# Type: <class 'str'>

# %% [markdown]
# ## Type Conversion
#
# Convert input to the required type:
#
# | Function | Converts to |
# |----------|------------|
# | `int()` | Integer |
# | `float()` | Decimal |
# | `str()` | String |

# %%
# Convert to integer
age = input('Enter your age: ')
age = int(age)
print('Type:', type(age))  # <class 'int'>
# Out:
# Type: <class 'int'>

# %%
# Convert to float
salary = input('Enter salary: ')
salary = float(salary)
print('Type:', type(salary))  # <class 'float'>
# Out:
# Type: <class 'float'>

# %%
# One-liner conversion
age = int(input('Enter your age: '))
salary = float(input('Enter salary: '))

# %% [markdown]
# ## Using eval()
#
# `eval()` evaluates a string as Python code. It auto-detects the type.

# %%
# Automatically becomes int
age = eval(input('Enter age: '))  # User types: 25
print(type(age))  # <class 'int'>
# Out:
# <class 'int'>

# %%
# Automatically becomes float
salary = eval(input('Enter salary: '))  # User types: 50000.50
print(type(salary))  # <class 'float'>
# Out:
# <class 'float'>

# %%
# Can even evaluate expressions
result = eval(input('Enter expression: '))  # User types: 10 + 20 * 3
print(result)  # 70
# Out:
# 70

# %% [markdown]
# **Warning:** `eval()` is risky with untrusted input - it executes any Python code!

# %% [markdown]
# ## Quick Reference
#
# ```python
# # Basic input
# name = input('Enter name: ')
#
# # Integer input
# age = int(input('Enter age: '))
#
# # Float input
# price = float(input('Enter price: '))
#
# # Auto-detect type (use carefully)
# value = eval(input('Enter value: '))
# ```

# %% [markdown]
# ---
#
# ## Practice

# %%
# Q1: Ask for a number, print its square and cube

num = int(input('Enter a number: '))
print('Square:', num ** 2)
print('Cube:', num ** 3)
# Out:
# Square: 10000
# Cube: 1000000

# %%
# Q2: Input 3 numbers, calculate total and average

n1 = float(input('Enter first number: '))
n2 = float(input('Enter second number: '))
n3 = float(input('Enter third number: '))

total = n1 + n2 + n3
avg = total / 3

print('Numbers:', n1, n2, n3)
print('Total:', total)
print('Average:', avg)
# Out:
# Numbers: 20.0 25.0 30.0
# Total: 75.0
# Average: 25.0

# %%
# Q3: Salary estimator
# HRA = 10% of basic, Conveyance = 3500

basic = float(input('Enter basic salary: '))
hra = basic * 0.10
conveyance = 3500
total_salary = basic + hra + conveyance

print('Basic:', basic)
print('HRA (10%):', hra)
print('Conveyance:', conveyance)
print('Total Salary:', total_salary)
# Out:
# Basic: 40000.0
# HRA (10%): 4000.0
# Conveyance: 3500
# Total Salary: 47500.0
